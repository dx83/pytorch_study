# %%
def pizza_price_model(size):
    weight = 2
    bias = 3
    price = weight * size + bias
    return price

# %%
size = 5
predicted_price = pizza_price_model(size)
print(f"{size}인치 피자 예상 가격: {predicted_price}천원")
# Out:
# 5인치 피자 예상 가격: 13천원

# %%
import torch
def forward_pass(x, W, b):  # 입력 텐서, 가중치 행렬, 바이어스
    z = torch.mm(x, W) + b  # 선형 변환: 가중치 곱셈과 바이어스 추가
    output = torch.relu(z)  # 활성화 함수 적용: ReLU를 사용하여 비선형성 추가
    return output

x = torch.tensor([[1.0, 2.0],
                  [3.0, 4.0]])

W = torch.tensor([[0.5, -0.5],
                  [1.0, 1.0]])

b = torch.tensor([[1.0, 1.0]])

output = forward_pass(x, W, b)
output
# Out:
# tensor([[3.5000, 2.5000],
#         [6.5000, 3.5000]])

# %%
# 간단한 성형 회귀 모델
import torch
import torch.nn as nn

x = torch.tensor([[1.0], [2.0], [3.0], [4.0]])
y_true = 2 * x + 1

# 임의의 모델 예측값
model_output = torch.tensor([[2.5], [3.5], [4.5], [5.5]])
# 손실 함수
criterion = nn.MSELoss()
# 손실 계산
loss = criterion(model_output, y_true)
print(f"손실 값 (MSE): {loss.item()}")
# Out:
# 손실 값 (MSE): 5.25

# %%
size = 5

actual_price = 11
predicted_price = 13
error = predicted_price - actual_price
print(f"오차: {error}처원 (너무 비싸게 예측)")
print("가중치를 조금 줄여야겠다...")

weight = 2
bias = 3

learning_rate = 0.01
weight = weight - learning_rate * error * size
bias = bias - learning_rate * error
print(f"새로운 가중치: {weight:.2f}, 새로운 편향: {bias:.2f}")
# Out:
# 오차: 2처원 (너무 비싸게 예측)
# 가중치를 조금 줄여야겠다...
# 새로운 가중치: 1.90, 새로운 편향: 2.98

# %%
 import torch
 x = torch.tensor(2.0, requires_grad=True)
 y = x**2 + 3*x + 4
 y.backward()
 print(f"x에 대한 기울기: {x.grad}")
# Out:
# x에 대한 기울기: 7.0

# %%
x = torch.tensor([[1.0, 2.0], [3.0, 4.0]], requires_grad=True)
y = (x**2).sum()
y.backward()
print(f"x의 기울기:\n {x.grad}")
# Out:
# x의 기울기:
#  tensor([[2., 4.],
#         [6., 8.]])

# %%
import torch
import torch.nn as nn
import torch.optim as optim

class LinearRegressionModel(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(LinearRegressionModel, self).__init__()
        self.linear = nn.Linear(input_dim, output_dim)
    
    def forward(self, x):
        return self.linear(x)

x = torch.tensor([[1.0], [2.0], [3.0], [4.0]])
y_true = 2* x + 1

model = LinearRegressionModel(1, 1)
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

for epoch in range(100):
    optimizer.zero_grad()
    pred = model(x)
    loss = criterion(pred, y_true)
    loss.backward()
    optimizer.step()

    if (epoch + 1) % 20 == 0:
        print(f"Epoch {epoch+1}, Loss: {loss.item():.4f}")
# Out:
# Epoch 20, Loss: 0.1369
# Epoch 40, Loss: 0.0691
# Epoch 60, Loss: 0.0613
# Epoch 80, Loss: 0.0544
# Epoch 100, Loss: 0.0482
